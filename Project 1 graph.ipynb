# %%
from os import listdir
listdir('downloads')
# Out:
# ['124_Textbook_Info.pdf',
#  '1641346995149.jpg',
#  'ACFrOgABUd8ejQVxoLpHL1BSd_X9qb5GLRipu90xJHg4tfR-GGO29ZJtupTAGjxeKoZSKaa8WpXq9RLsuVVEtpkS4LkVVdOQwbS0epZasdlvi-bOCUX8IcnhGTjQsRQ=.pdf',
#  'activity_directory_treasure_hunt',
#  'activity_directory_treasure_hunt.zip',
#  'Anaconda3-2021.11-Windows-x86_64.exe',
#  'Anzaldua-Wild-Tongue.pdf',
#  'ApexLegendsInstaller.exe',
#  'bccalcet03_0001.cdf',
#  'Bcore BS.pdf',
#  'Bcore democracy and truth reading.pdf',
#  'Bcore final check in.pdf',
#  'BCORE Final reflection.pdf',
#  'Bcore Reflectin week 5.pdf',
#  'Bcore reflection week 2.pdf',
#  'BCORE reflection week 3.pdf',
#  'Bcore reflection week 4.pdf',
#  'BCORE voting rights rhetoric.pdf',
#  'BCORE107 Final Project Planning Document-1 (1).docx',
#  'BCORE107 Final Project Planning Document-1.docx',
#  'BCORE107 Final Project Planning Document-1.pdf',
#  'Bellhooks writing .pdf',
#  'Calc exam 1 (1).pdf',
#  'Calc exam 1.pdf',
#  'ChromeSetup.exe',
#  'Dataset_1_Unemployment_Claims_Snohomish_2005_2021_Initial_Claims (1).csv',
#  'Dataset_1_Unemployment_Claims_Snohomish_2005_2021_Initial_Claims (2).csv',
#  'Dataset_1_Unemployment_Claims_Snohomish_2005_2021_Initial_Claims (3).csv',
#  'Dataset_1_Unemployment_Claims_Snohomish_2005_2021_Initial_Claims.csv',
#  'desktop.ini',
#  'DiscordSetup (1).exe',
#  'DiscordSetup (2).exe',
#  'DiscordSetup (3).exe',
#  'DiscordSetup (4).exe',
#  'DiscordSetup (5).exe',
#  'DiscordSetup.exe',
#  'EC202009.pdf',
#  'Educational narritive.pdf',
#  'Exam 1 Practice STMATH 124 Wi 22.pdf',
#  'example_data - Sheet1 (1).csv',
#  'example_data - Sheet1.csv',
#  'IMG_20210627_231152_224.jpg',
#  'Install League of Legends na.exe',
#  'Install VALORANT.exe',
#  'Lecture 1 Class Notes A - precalc review and 2.1.pdf',
#  'Lecture 1 Neat Notes - precalc review and 2.1.pdf',
#  'Lecture 2 Class Notes A - 2.2 and 2.3.pdf',
#  'Lecture 3 and 4 Neat Notes - 2.3 (continued) and 2.4.pdf',
#  'Lecture 5 Neat Notes - 2.5.pdf',
#  'LineInst.exe',
#  'Literature synthesis #1.pdf',
#  'Literature_Review_Template (1).xlsx',
#  'Literature_Review_Template.xlsx',
#  'Log_DigitalITOWrapper.txt',
#  'Midterm Exam 1 Part 2 124 Wi 22.pdf',
#  'mylivewallpapers.com-Sasuke-Uchiha-Lightning-Naruto-Shippuden.mp4',
#  'osu!install.exe',
#  'Problem-1 (1).pdf',
#  'Problem-1.pdf',
#  'PXL_20210516_185656253.jpg',
#  'PXL_20210526_195112289.jpg',
#  'PXL_20210821_184244863.jpg',
#  'PXL_20210914_205724575.MP.jpg',
#  'PXL_20210914_205813041.MP.jpg',
#  'PXL_20211008_005503889.MP.jpg',
#  'PXL_20220105_183945943.MP.jpg',
#  'PXL_20220105_183950571.MP.jpg',
#  'PXL_20220105_183954286.MP.jpg',
#  'PXL_20220105_183958711.MP.jpg',
#  'PXL_20220107_183226624.MP.jpg',
#  'PXL_20220107_183231010.MP.jpg',
#  'PXL_20220107_183234422.MP.jpg',
#  'PXL_20220107_183237654.MP.jpg',
#  'PXL_20220107_183242204.MP.jpg',
#  'PXL_20220113_215941565.MP.jpg',
#  'PXL_20220113_215954981.MP.jpg',
#  'PXL_20220113_220015437.MP.jpg',
#  'PXL_20220113_220028264.MP.jpg',
#  'PXL_20220113_220051122.MP.jpg',
#  'PXL_20220113_220120731.MP.jpg',
#  'PXL_20220113_220133542.MP.jpg',
#  'PXL_20220114_181707780.MP.jpg',
#  'PXL_20220114_181738943.MP.jpg',
#  'PXL_20220114_182958195.MP.jpg',
#  'PXL_20220114_190645708.MP.jpg',
#  'PXL_20220114_190649589.MP.jpg',
#  'PXL_20220114_190709743.MP.jpg',
#  'PXL_20220114_190720729.MP.jpg',
#  'PXL_20220114_190725217.MP.jpg',
#  'PXL_20220121_161902623.MP.jpg',
#  'PXL_20220121_161913117.MP.jpg',
#  'PXL_20220121_161930595.MP.jpg',
#  'PXL_20220121_162016029.MP.jpg',
#  'PXL_20220121_162407683.MP.jpg',
#  'PXL_20220124_233418218.MP.jpg',
#  'PXL_20220128_174825152.MP.jpg',
#  'PXL_20220128_174834182.MP.jpg',
#  'PXL_20220128_174840220.MP.jpg',
#  'PXL_20220128_174851146.MP.jpg',
#  'PXL_20220128_174908340.MP.jpg',
#  'PXL_20220128_174916311.MP.jpg',
#  'PXL_20220128_174957190.MP.jpg',
#  'PXL_20220128_175153655.MP.jpg',
#  'PXL_20220128_175202685.MP.jpg',
#  'PXL_20220128_175211118.MP.jpg',
#  'PXL_20220128_175218682.MP.jpg',
#  'PXL_20220201_192206716.MP.jpg',
#  'PXL_20220201_193044176.MP.jpg',
#  'quiz 1 #2.pdf',
#  'quiz 1 (1).pdf',
#  'Quiz 1 STMATH 124 A Wi 21 (1).pdf',
#  'Quiz 1 STMATH 124 A Wi 21.pdf',
#  'quiz 1.pdf',
#  'Roberts-Miller - Demagoguery and Democracy Ch1-4-1.pdf',
#  'Scanned Documents.pdf',
#  'schedule.JPG',
#  'Screenshot 2022-02-01 112023.jpg',
#  'Self Evaluation Form.doc',
#  'SeriesReport-20220131193442_0e7e69.xlsx',
#  'SeriesReport-20220131193529_8a94c6.xlsx',
#  'SeriesReport-20220215162716_8a543a.xlsx',
#  'SteamSetup.exe',
#  'Titus_Hist.docx',
#  'Transcript Grades Spring 2021.docx',
#  'Treatment_Results.csv',
#  'Unemployment rate in Washington - Sheet1.csv',
#  'Unemployment_Claims_Snohomish_2005_2021_Initial_Claims.csv',
#  'UPS CampusShip _ UPS - United States-daria.pdf',
#  'villanueva.pdf',
#  'Wolfram Player 13.0',
#  'WolframPlayer_13.0.0_WIN_EXP.exe',
#  'WOrk Sheet 1.pdf',
#  'Worksheet 0 Precalc Reviev.pdf',
#  'worksheet 0.pdf',
#  'Worksheet 1 Part 1 2.1 and 2.2 (1).pdf',
#  'Worksheet 1 Part 1 2.1 and 2.2.pdf',
#  'Worksheet 1 Part 2 2.3.pdf',
#  'Worksheet 2 Part 2 2.6.pdf',
#  'Worksheet 3 3.1 and 3.2.pdf',
#  'Worksheet 4 Part 1 3.3.pdf',
#  'Worksheet 4 Part 1 3.4.pdf',
#  'Worksheet 4 Part 2 - 3.4.pdf',
#  'Worksheet 4.pdf',
#  'wp8270117-solo-leveling-live-wallpapers.jpg',
#  'Writing history (1) (1).docx',
#  'Writing history (1).docx',
#  'Writing history (1).pdf',
#  'Writing history.docx',
#  'Writing history.pdf',
#  'ZoomInstaller.exe',
#  'zotero',
#  'Zotero-5.0.96.3_setup.exe']

# %%
import pandas as pd
df = pd.read_csv('downloads/Unemployment rate in Washington - Sheet1.csv')
df.head(36)
# Out:
#     Year Period  labor force participation rate  employment-population ratio  \
# 0   2019    Jan                            64.7                         61.7
# 1   2019    Feb                            64.7                         61.8
# 2   2019    Mar                            64.7                         61.9
# 3   2019    Apr                            64.8                         62.0
# 4   2019    May                            64.8                         62.1
# 5   2019    Jun                            64.9                         62.2
# 6   2019    Jul                            65.0                         62.3
# 7   2019    Aug                            65.1                         62.4
# 8   2019    Sep                            65.1                         62.5
# 9   2019    Oct                            65.1                         62.6
# 10  2019    Nov                            65.2                         62.7
# 11  2019    Dec                            65.2                         62.7
# 12  2020    Jan                            65.2                         62.6
# 13  2020    Feb                            65.2                         62.6
# 14  2020    Mar                            64.7                         61.3
# 15  2020    Apr                            65.5                         54.8
# 16  2020    May                            64.1                         56.1
# 17  2020    Jun                            63.6                         56.7
# 18  2020    Jul                            64.3                         57.3
# 19  2020    Aug                            63.6                         57.8
# 20  2020    Sep                            63.3                         58.2
# 21  2020    Oct                            65.1                         60.5
# 22  2020    Nov                            62.7                         58.6
# 23  2020    Dec                            62.5                         58.6
# 24  2021    Jan                            62.5                         58.8
# 25  2021    Feb                            62.5                         59.0
# 26  2021    Mar                            62.7                         59.2
# 27  2021    Apr                            62.8                         59.4
# 28  2021    May                            62.9                         59.6
# 29  2021    Jun                            63.1                         59.8
# 30  2021    Jul                            63.3                         60.1
# 31  2021    Aug                            63.5                         60.3
# 32  2021    Sep                            63.5                         60.3
# 33  2021    Oct                            63.6                         60.4
# 34  2021    Nov                            63.6                         60.6
# 35  2021    Dec                            63.8                         60.9
#
#     labor force  change/month  employment  unemployment  \
# 0       3869370           NaN     3694099        175271
# 1       3875239      5,869.00     3702019        173220
# 2       3880632      5,393.00     3710734        169898
# 3       3887284      6,652.00     3720954        166330
# 4       3895753      8,469.00     3732380        163373
# 5       3905366      9,613.00     3743850        161516
# 6       3915017      9,651.00     3754579        160438
# 7       3923782      8,765.00     3764361        159421
# 8       3931891      8,109.00     3774351        157540
# 9       3939393      7,502.00     3784478        154915
# 10      3945768      6,375.00     3792879        152889
# 11      3951421      5,653.00     3798056        153365
# 12      3957004      5,583.00     3799953        157051
# 13      3961975      4,971.00     3799304        162671
# 14      3932003   (29,972.00)     3724793        207210
# 15      3988363     56,360.00     3336286        652077
# 16      3904883   (83,480.00)     3417587        487296
# 17      3877618   (27,265.00)     3457295        420323
# 18      3920431     42,813.00     3497219        423212
# 19      3886077   (34,354.00)     3532848        353229
# 20      3870014   (16,063.00)     3560713        309301
# 21      3981810    111,796.00     3704008        277802
# 22      3842951  (138,859.00)     3586497        256454
# 23      3830416   (12,535.00)     3590957        239459
# 24      3835229      4,813.00     3606638        228591
# 25      3837024      1,795.00     3621472        215552
# 26      3850738     13,714.00     3639937        210801
# 27      3861172     10,434.00     3651768        209404
# 28      3873466     12,294.00     3670293        203173
# 29      3887109     13,643.00     3685476        201633
# 30      3906287     19,178.00     3707080        199207
# 31      3922962     16,675.00     3724144        198818
# 32      3928041      5,079.00     3729358        198683
# 33      3934975      6,934.00     3736862        198113
# 34      3937865      2,890.00     3752206        185659
# 35      3952917     15,052.00     3776060        176857
#
#     Unemployment decrease/increase  unemployment rate  \
# 0                              NaN                4.5
# 1                          -2051.0                4.5
# 2                          -3322.0                4.4
# 3                          -3568.0                4.3
# 4                          -2957.0                4.2
# 5                          -1857.0                4.1
# 6                          -1078.0                4.1
# 7                          -1017.0                4.1
# 8                          -1881.0                4.0
# 9                          -2625.0                3.9
# 10                         -2026.0                3.9
# 11                           476.0                3.9
# 12                          3686.0                4.0
# 13                          5620.0                4.1
# 14                         44539.0                5.3
# 15                        444867.0               16.3
# 16                       -164781.0               12.5
# 17                        -66973.0               10.8
# 18                          2889.0               10.8
# 19                        -69983.0                9.1
# 20                        -43928.0                8.0
# 21                        -31499.0                7.0
# 22                        -21348.0                6.7
# 23                        -16995.0                6.3
# 24                        -10868.0                6.0
# 25                        -13039.0                5.6
# 26                         -4751.0                5.5
# 27                         -1397.0                5.4
# 28                         -6231.0                5.2
# 29                         -1540.0                5.2
# 30                         -2426.0                5.1
# 31                          -389.0                5.1
# 32                          -135.0                5.1
# 33                          -570.0                5.0
# 34                        -12454.0                4.7
# 35                         -8802.0                4.5
#
#    Unemployment rate increase/decrease
# 0                                  NaN
# 1                                0.00%
# 2                              -10.00%
# 3                              -10.00%
# 4                              -10.00%
# 5                              -10.00%
# 6                                0.00%
# 7                                0.00%
# 8                              -10.00%
# 9                              -10.00%
# 10                               0.00%
# 11                               0.00%
# 12                              10.00%
# 13                              10.00%
# 14                             120.00%
# 15                            1100.00%
# 16                            -380.00%
# 17                            -170.00%
# 18                               0.00%
# 19                            -170.00%
# 20                            -110.00%
# 21                            -100.00%
# 22                             -30.00%
# 23                             -40.00%
# 24                             -30.00%
# 25                             -40.00%
# 26                             -10.00%
# 27                             -10.00%
# 28                             -20.00%
# 29                               0.00%
# 30                             -10.00%
# 31                               0.00%
# 32                               0.00%
# 33                             -10.00%
# 34                             -30.00%
# 35                             -20.00%

# %%
y = list(df['unemployment rate'])
x = list(df['Period'])
z = list(df['Year'])

import matplotlib.pyplot as plt

plt.scatter(x,y,c=z, cmap='magma')
plt.xlabel("Period")
plt.ylabel("unemployment rate")

print("2019=black","2020=red","2021=yellow")
# Out:
# 2019=black 2020=red 2021=yellow

# %%
y = list(df['unemployment'])
x = list(df['Period'])
z = list(df['Year'])

import matplotlib.pyplot as plt

plt.scatter(x,y,c=z, cmap='magma')
plt.xlabel("Period")
plt.ylabel("unemployment")

print("2019=black","2020=red","2021=yellow")
# Out:
# 2019=black 2020=red 2021=yellow
